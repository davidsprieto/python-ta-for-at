# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cufflinks as cf
from plotly.offline import plot
import yfinance as yf
from datetime import date as date
from dotenv import load_dotenv
import os
from requests import Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %% [markdown]
# # Retrieving Data from Yahoo Finance

# %%
start_date = '2019-09-18'
end_date = date.today()
symbol = 'HBAR-USD'
yf_data = yf.download(symbol, start_date, end_date)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df = yf.download(tickers=symbol, start=start_date, end=end_date)
print(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker      HBAR-USD  HBAR-USD  HBAR-USD  HBAR-USD   HBAR-USD
# Date
# 2019-09-18  0.086921  0.100272  0.080045  0.090519   14772274
# 2019-09-19  0.057924  0.087721  0.054469  0.087702   27324784
# 2019-09-20  0.052490  0.059061  0.047800  0.058087   15814443
# 2019-09-21  0.048021  0.055408  0.045456  0.052402   13144171
# 2019-09-22  0.039735  0.048237  0.038757  0.048065   10549578
# ...              ...       ...       ...       ...        ...
# 2025-02-22  0.216522  0.222497  0.212172  0.213206  203206881
# 2025-02-23  0.211499  0.217559  0.208068  0.216522  146242049
# 2025-02-24  0.196241  0.225975  0.195948  0.211459  679383267
# 2025-02-25  0.197179  0.200841  0.176010  0.196248  710497590
# 2025-02-26  0.197757  0.201235  0.188126  0.197843  422099848
#
# [1989 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1989 entries, 2019-09-18 to 2025-02-26
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, HBAR-USD)   1989 non-null   float64
#  1   (High, HBAR-USD)    1989 non-null   float64
#  2   (Low, HBAR-USD)     1989 non-null   float64
#  3   (Open, HBAR-USD)    1989 non-null   float64
#  4   (Volume, HBAR-USD)  1989 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 93.2 KB

# %%
symbol = ["MSFT", "GE", "AAPL"]

# %%
df = yf.download(tickers=symbol, start=start_date, end=end_date)
df
# Out:
# [*********************100%***********************]  3 of 3 completed
# Price            Close                                High              \
# Ticker            AAPL          GE        MSFT        AAPL          GE
# Date
# 2019-09-18   53.772179   45.687977  131.778809   53.791489   45.736682
# 2019-09-19   53.335274   45.882797  134.204727   54.011134   46.272460
# 2019-09-20   52.555614   45.639259  132.654053   53.721479   46.467295
# 2019-09-23   52.794575   45.493145  132.368652   53.064919   45.736684
# 2019-09-24   52.543552   43.690952  130.694290   53.704592   45.541850
# ...                ...         ...         ...         ...         ...
# 2025-02-20  245.830002  208.740005  416.130005  246.779999  210.279999
# 2025-02-21  245.550003  199.830002  408.209991  248.690002  209.119995
# 2025-02-24  247.100006  198.710007  404.000000  248.860001  203.250000
# 2025-02-25  247.039993  199.270004  397.899994  250.000000  200.080002
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1368 entries, 2019-09-18 to 2025-02-26
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   1368 non-null   float64
#  1   (Close, GE)     1368 non-null   float64
#  2   (Close, MSFT)   1368 non-null   float64
#  3   (High, AAPL)    1368 non-null   float64
#  4   (High, GE)      1368 non-null   float64
#  5   (High, MSFT)    1368 non-null   float64
#  6   (Low, AAPL)     1368 non-null   float64
#  7   (Low, GE)       1368 non-null   float64
#  8   (Low, MSFT)     1368 non-null   float64
#  9   (Open, AAPL)    1368 non-null   float64
#  10  (Open, GE)      1368 non-null   float64
#  11  (Open, MSFT)    1368 non-null   float64
#  12  (Volume, AAPL)  1368 non-null   int64
#  13  (Volume, GE)    1368 non-null   int64
#  14  (Volume, MSFT)  1368 non-null   int64
# dtypes: float64(12), int64(3)
# memory usage: 171.0 KB

# %%
# Save dataframe to a CSV file
df.to_csv("stocks.csv")

# %% [markdown]
# # Retrieving Data from CoinMarketCap API

# %%
# CoinMarketCap API_KEY
load_dotenv()
API_KEY = os.getenv("API_KEY")

# %%
crypto_ids_url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/map'
parameters = {
  'limit':'50',
}
headers = {
  'Accepts': 'application/json',
  'Accept-Encoding': 'deflate, gzip',
  'X-CMC_PRO_API_KEY': API_KEY,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(crypto_ids_url, params=parameters)
  data = json.loads(response.text)
  print(json.dumps(data, indent=4))
  session.close()
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
  session.close()
# Out:
# {
#     "status": {
#         "timestamp": "2025-02-28T01:06:37.901Z",
#         "error_code": 0,
#         "error_message": null,
#         "elapsed": 541,
#         "credit_count": 1,
#         "notice": null
#     },
#     "data": [
#         {
#             "id": 1,
#             "rank": 1,
#             "name": "Bitcoin",
#             "symbol": "BTC",
#             "slug": "bitcoin",
#             "is_active": 1,
#             "status": 1,
#             "first_historical_data": "2010-07-13T00:05:00.000Z",
#             "last_historical_data": "2025-02-28T00:50:00.000Z",
#             "platform": null
#         },
#         {
#             "id": 2,
#             "rank": 12,
#             "name": "Litecoin",
#             "symbol": "LTC",
#             "slug": "litecoin",
#             "is_active": 1,
#             "status": 1,
#             "first_historical_data": "2013-04-28T18:45:00.000Z",
#             "last_historical_data": "2025-02-28T00:50:00.000Z",
# ...

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/quotes/latest'
parameters = {
    'id': '4642',
    'convert': 'USD'
}
headers = {
    'Accepts': 'application/json',
    'Accept-Encoding': 'deflate, gzip',
    'X-CMC_PRO_API_KEY': API_KEY
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters, headers=headers)
    data = json.loads(response.text)
    print(json.dumps(data, indent=4))
    session.close()
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)
    session.close()
# Out:
# {
#     "status": {
#         "timestamp": "2025-02-28T01:06:38.894Z",
#         "error_code": 0,
#         "error_message": null,
#         "elapsed": 52,
#         "credit_count": 1,
#         "notice": null
#     },
#     "data": {
#         "4642": {
#             "id": 4642,
#             "name": "Hedera",
#             "symbol": "HBAR",
#             "slug": "hedera",
#             "num_market_pairs": 319,
#             "date_added": "2019-09-17T00:00:00.000Z",
#             "tags": [
#                 "dag",
#                 "marketplace",
#                 "enterprise-solutions",
#                 "defi",
#                 "payments",
#                 "dcg-portfolio",
#                 "hedera-hashgraph-ecosystem",
#                 "real-world-assets",
#                 "layer-1",
#                 "made-in-america"
#             ],
#             "max_supply": 50000000000,
#             "circulating_supply": 41903956526.05019,
#             "total_supply": 50000000000,
# ...

# %% [markdown]
# # Charting - Simple Line Charts

# %%
df = pd.read_csv('stocks.csv', header=[0, 1], index_col=0, parse_dates=[0])

# %%
df
# Out:
# Price            Close                                High              \
# Ticker            AAPL          GE        MSFT        AAPL          GE
# Date
# 2019-09-18   53.772179   45.687977  131.778809   53.791489   45.736682
# 2019-09-19   53.335274   45.882797  134.204727   54.011134   46.272460
# 2019-09-20   52.555614   45.639259  132.654053   53.721479   46.467295
# 2019-09-23   52.794575   45.493145  132.368652   53.064919   45.736684
# 2019-09-24   52.543552   43.690952  130.694290   53.704592   45.541850
# ...                ...         ...         ...         ...         ...
# 2025-02-20  245.830002  208.740005  416.130005  246.779999  210.279999
# 2025-02-21  245.550003  199.830002  408.209991  248.690002  209.119995
# 2025-02-24  247.100006  198.710007  404.000000  248.860001  203.250000
# 2025-02-25  247.039993  199.270004  397.899994  250.000000  200.080002
# 2025-02-26  240.360001  201.610001  399.730011  244.979996  204.600006
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1368 entries, 2019-09-18 to 2025-02-26
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   1368 non-null   float64
#  1   (Close, GE)     1368 non-null   float64
#  2   (Close, MSFT)   1368 non-null   float64
#  3   (High, AAPL)    1368 non-null   float64
#  4   (High, GE)      1368 non-null   float64
#  5   (High, MSFT)    1368 non-null   float64
#  6   (Low, AAPL)     1368 non-null   float64
#  7   (Low, GE)       1368 non-null   float64
#  8   (Low, MSFT)     1368 non-null   float64
#  9   (Open, AAPL)    1368 non-null   float64
#  10  (Open, GE)      1368 non-null   float64
#  11  (Open, MSFT)    1368 non-null   float64
#  12  (Volume, AAPL)  1368 non-null   int64
#  13  (Volume, GE)    1368 non-null   int64
#  14  (Volume, MSFT)  1368 non-null   int64
# dtypes: float64(12), int64(3)
# memory usage: 171.0 KB

# %%
# Select only GE Close prices
ge_close_prices = df.Close["GE"]
ge_close_prices
# Out:
# Date
# 2019-09-18     45.687977
# 2019-09-19     45.882797
# 2019-09-20     45.639259
# 2019-09-23     45.493145
# 2019-09-24     43.690952
#                  ...
# 2025-02-20    208.740005
# 2025-02-21    199.830002
# 2025-02-24    198.710007
# 2025-02-25    199.270004
# 2025-02-26    201.610001
# Name: GE, Length: 1368, dtype: float64

# %%
# Plot only GE Close Prices
ge_close_prices.plot(figsize=(12,8))
plt.show()

# %%
df.loc["2020-06", ("Close", "GE")].plot(figsize=(12,8))
plt.show()

# %% [markdown]
# # Charting - Interactive Line Charts with Cufflinks and Plotly

# %%
df
# Out:
# Price            Close                                High              \
# Ticker            AAPL          GE        MSFT        AAPL          GE
# Date
# 2019-09-18   53.772179   45.687977  131.778809   53.791489   45.736682
# 2019-09-19   53.335274   45.882797  134.204727   54.011134   46.272460
# 2019-09-20   52.555614   45.639259  132.654053   53.721479   46.467295
# 2019-09-23   52.794575   45.493145  132.368652   53.064919   45.736684
# 2019-09-24   52.543552   43.690952  130.694290   53.704592   45.541850
# ...                ...         ...         ...         ...         ...
# 2025-02-20  245.830002  208.740005  416.130005  246.779999  210.279999
# 2025-02-21  245.550003  199.830002  408.209991  248.690002  209.119995
# 2025-02-24  247.100006  198.710007  404.000000  248.860001  203.250000
# 2025-02-25  247.039993  199.270004  397.899994  250.000000  200.080002
# 2025-02-26  240.360001  201.610001  399.730011  244.979996  204.600006
#
# ...

# %%
cf.set_config_file(offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.0.min"</script>

# %%
df.loc["2020-06":, ("Close", "GE")].iplot(asFigure = True, colorscale = "plotly")
# Out:
# /Users/david/IdeProjects/python-ml-trading/python-ml-trading/.venv/lib/python3.12/site-packages/cufflinks/plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.loc["2020-06":, ("Close", "GE")].iplot(asFigure = True, colorscale = "plotly")
#
# ...

# %%
df.Close.iplot()
